# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
trader_df=pd.read_csv(r"D:\project internshala\fear_greed_index.csv")
sentiment_df=pd.read_csv(r"D:\project internshala\historical_data.csv")

# %%
trader_df.head()
sentiment_df.head()
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# ...

# %%
trader_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       2644 non-null   int64
#  1   value           2644 non-null   int64
#  2   classification  2644 non-null   object
#  3   date            2644 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 82.8+ KB

# %%
sentiment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  object
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
# ...

# %%
#converting to the date time format because it has unix time stamp
trader_df['datetime']=pd.to_datetime(trader_df['timestamp'], unit='s')
#now i want to extract
trader_df['date']=trader_df['datetime'].dt.date
trader_df[['timestamp', 'datetime', 'date']].head()
# Out:
#     timestamp            datetime        date
# 0  1517463000 2018-02-01 05:30:00  2018-02-01
# 1  1517549400 2018-02-02 05:30:00  2018-02-02
# 2  1517635800 2018-02-03 05:30:00  2018-02-03
# 3  1517722200 2018-02-04 05:30:00  2018-02-04
# 4  1517808600 2018-02-05 05:30:00  2018-02-05

# %%
sentiment_df['date']=pd.to_datetime(sentiment_df['Timestamp'],errors='coerce').dt.date

# %%
sentiment_df[['Timestamp','date']].head()
# Out:
#       Timestamp        date
# 0  1.730000e+12  1970-01-01
# 1  1.730000e+12  1970-01-01
# 2  1.730000e+12  1970-01-01
# 3  1.730000e+12  1970-01-01
# 4  1.730000e+12  1970-01-01

# %%
sentiment_df=pd.read_csv(r"D:\project internshala\historical_data.csv")

# %%
sentiment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  object
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
# ...

# %%
sentiment_df.head()
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# ...

# %%
sentiment_df['Timestamp'].head()
# Out:
# 0    1.730000e+12
# 1    1.730000e+12
# 2    1.730000e+12
# 3    1.730000e+12
# 4    1.730000e+12
# Name: Timestamp, dtype: float64

# %%
sentiment_df['Timestamp'].dtype
# Out:
# dtype('float64')

# %%
sentiment_df['Timestamp']=sentiment_df['Timestamp'].astype('int64')

# %%
sentiment_df['datetime']=pd.to_datetime(sentiment_df['Timestamp'],unit='ms',errors='coerce')

# %%
sentiment_df['date']=sentiment_df['datetime'].dt.date

# %%
sentiment_df[['Timestamp','datetime','date']].head()
# Out:
#        Timestamp            datetime        date
# 0  1730000000000 2024-10-27 03:33:20  2024-10-27
# 1  1730000000000 2024-10-27 03:33:20  2024-10-27
# 2  1730000000000 2024-10-27 03:33:20  2024-10-27
# 3  1730000000000 2024-10-27 03:33:20  2024-10-27
# 4  1730000000000 2024-10-27 03:33:20  2024-10-27

# %%
merged_df=sentiment_df.merge(trader_df[['date','classification']],on='date',how='left')

# %%
merged_df[['date','classification']].head(10)
# Out:
#          date classification
# 0  2024-10-27          Greed
# 1  2024-10-27          Greed
# 2  2024-10-27          Greed
# 3  2024-10-27          Greed
# 4  2024-10-27          Greed
# 5  2024-10-27          Greed
# 6  2024-10-27          Greed
# 7  2024-10-27          Greed
# 8  2024-10-27          Greed
# 9  2024-10-27          Greed

# %%
trader_df['date'].min(),trader_df['date'].max()
# Out:
# (datetime.date(2018, 2, 1), datetime.date(2025, 5, 2))

# %%
sentiment_df['date'].min()
sentiment_df['date'].max()
# Out:
# datetime.date(2025, 6, 15)

# %%
sentiment_df['Timestamp'].head()
# Out:
# 0    1730000000000
# 1    1730000000000
# 2    1730000000000
# 3    1730000000000
# 4    1730000000000
# Name: Timestamp, dtype: int64

# %%
sentiment_df['datetime']=pd.to_datetime(sentiment_df['Timestamp'],unit='ms')
sentiment_df['date']=sentiment_df['datetime'].dt.date

# %%
sentiment_df['date'].min()
sentiment_df['date'].max()
# Out:
# datetime.date(2025, 6, 15)

# %%
pd.to_datetime(trader_df['timestamp'],unit='ms')
# Out:
# 0      1970-01-18 13:31:03.000
# 1      1970-01-18 13:32:29.400
# 2      1970-01-18 13:33:55.800
# 3      1970-01-18 13:35:22.200
# 4      1970-01-18 13:36:48.600
#                  ...
# 2639   1970-01-21 04:56:58.200
# 2640   1970-01-21 04:58:24.600
# 2641   1970-01-21 04:59:51.000
# 2642   1970-01-21 05:01:17.400
# 2643   1970-01-21 05:02:43.800
# Name: timestamp, Length: 2644, dtype: datetime64[ns]

# %%
trader_df['datetime']=pd.to_datetime(trader_df['timestamp'],unit='s')

# %%
trader_df['date']=trader_df['datetime'].dt.date

# %%
trader_df['date'].min()
trader_df['date'].max()
# Out:
# datetime.date(2025, 5, 2)

# %%
merged_df=sentiment_df.merge(trader_df[['date','classification']],on='date',how='left')

# %%
merged_df.info()
merged_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  object
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
#  15  Timestamp         211224 non-null  int64
# ...

# %%
merged_df['classification'].value_counts()
# Out:
# classification
# Fear             133871
# Greed             36289
# Neutral            7141
# Extreme Greed      6962
# Name: count, dtype: int64

# %%
#analysis stage

# %%
#Average PnL by sentiment
merged_df.groupby('classification')['Closed PnL'].mean()
# Out:
# classification
# Extreme Greed    25.418772
# Fear             50.047622
# Greed            87.894859
# Neutral          22.229713
# Name: Closed PnL, dtype: float64

# %%
#Win rate by sentiment
merged_df['win']=merged_df['Closed PnL']>0
merged_df.groupby('classification')['win'].mean()
# Out:
# classification
# Extreme Greed    0.490089
# Fear             0.415146
# Greed            0.446471
# Neutral          0.317182
# Name: win, dtype: float64

# %%
#Number of trades by sentiment
merged_df['classification'].value_counts(normalize=True)
# Out:
# classification
# Fear             0.726521
# Greed            0.196941
# Neutral          0.038754
# Extreme Greed    0.037783
# Name: proportion, dtype: float64
